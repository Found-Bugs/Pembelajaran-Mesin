# %% [markdown]
# <a href="https://colab.research.google.com/github/Found-Bugs/Pembelajaran-Mesin/blob/Optical-Character-Recognition/Tugas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install -y tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 57 not upgraded.
# ...

# %%
import cv2
import pytesseract
from matplotlib import pyplot as plt

# %%
# Path ke file gambar
image_path = '/content/drive/MyDrive/ML/Dataset/OCR/hitchhikers-rotated.png'

# Membaca gambar menggunakan OpenCV
image = cv2.imread(image_path)

# Konversi gambar ke RGB (OpenCV menggunakan BGR secara default)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Menampilkan gambar asli
plt.figure(figsize=(8, 8))
plt.imshow(image_rgb)
plt.title("Original Image")
plt.axis('off')
plt.show()

# %%
# Menggunakan Tesseract untuk mendeteksi orientasi dan skrip
custom_config = r'--psm 0'  # Mode untuk mendeteksi orientasi
result = pytesseract.image_to_osd(image, config=custom_config)

# Menampilkan hasil orientasi dan jenis skrip
print("Detection Result:")
print(result)
# Out:
# Detection Result:
# Page number: 0
# Orientation in degrees: 270
# Rotate: 90
# Orientation confidence: 17.90
# Script: Latin
# Script confidence: 2.25
